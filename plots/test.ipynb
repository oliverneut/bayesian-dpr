# %%
import ir_datasets

# %%
trec_dl_19 = ir_datasets.load("msmarco-passage/trec-dl-2019/judged")

# %%
trec = trec_dl_19.qrels_dict()
trec['19335']
# Out:
# {'1017759': 0,
#  '1082489': 0,
#  '109063': 0,
#  '1160863': 0,
#  '1160871': 0,
#  '1189088': 0,
#  '1203500': 0,
#  '1231806': 0,
#  '1231807': 0,
#  '1274615': 0,
#  '1274620': 0,
#  '1324075': 0,
#  '1509459': 0,
#  '1555317': 0,
#  '1568085': 0,
#  '161603': 0,
#  '1705525': 0,
#  '1720387': 0,
#  '1720388': 0,
#  '1720389': 1,
#  '1720393': 0,
#  '1720395': 1,
#  '1722': 0,
#  '1725697': 0,
#  '1726': 0,
#  '1729': 2,
#  '1730': 0,
#  '1796642': 0,
#  '1796647': 0,
#  '1825416': 0,
#  '1825418': 0,
#  '1837110': 0,
#  '1871222': 0,
#  '1908804': 0,
#  '1956669': 0,
#  '1958100': 0,
#  '1958102': 0,
#  '1958103': 0,
#  '1959553': 0,
#  '2004186': 0,
#  '2046505': 1,
#  '2071723': 0,
#  '2130187': 0,
#  '2186129': 0,
#  '2304004': 0,
#  '2304005': 0,
#  '2324839': 0,
#  '2325143': 0,
#  '2382766': 0,
#  '2394677': 0,
#  '256744': 0,
#  '256746': 0,
#  '256750': 0,
#  '2594897': 0,
#  '2604487': 0,
#  '2725017': 0,
#  '2874503': 0,
#  '2943092': 0,
#  '2978577': 0,
# ...

# %%
for q in trec_dl_19.queries:
    print(q.query_id, q.text)
    break
# Out:
# [INFO] Please confirm you agree to the MSMARCO data usage agreement found at <http://www.msmarco.org/dataset.aspx>
# [INFO] [starting] https://trec.nist.gov/data/deep/2019qrels-pass.txt
# [INFO] [finished] https://trec.nist.gov/data/deep/2019qrels-pass.txt: [00:00] [187kB] [6.19MB/s]
# [INFO] [starting] https://msmarco.z22.web.core.windows.net/msmarcoranking/msmarco-test2019-queries.tsv.gz
# [INFO] [finished] https://msmarco.z22.web.core.windows.net/msmarcoranking/msmarco-test2019-queries.tsv.gz: [00:00] [4.28kB] [14.6MB/s]
# 156493 do goldfish grow

# %%
len(list(trec_dl_19.qrels_iter()))
# Out:
# 9260

# %%
trec_dl_19.qrels_dict()['19335']
# Out:
# {'1017759': 0,
#  '1082489': 0,
#  '109063': 0,
#  '1160863': 0,
#  '1160871': 0,
#  '1189088': 0,
#  '1203500': 0,
#  '1231806': 0,
#  '1231807': 0,
#  '1274615': 0,
#  '1274620': 0,
#  '1324075': 0,
#  '1509459': 0,
#  '1555317': 0,
#  '1568085': 0,
#  '161603': 0,
#  '1705525': 0,
#  '1720387': 0,
#  '1720388': 0,
#  '1720389': 1,
#  '1720393': 0,
#  '1720395': 1,
#  '1722': 0,
#  '1725697': 0,
#  '1726': 0,
#  '1729': 2,
#  '1730': 0,
#  '1796642': 0,
#  '1796647': 0,
#  '1825416': 0,
#  '1825418': 0,
#  '1837110': 0,
#  '1871222': 0,
#  '1908804': 0,
#  '1956669': 0,
#  '1958100': 0,
#  '1958102': 0,
#  '1958103': 0,
#  '1959553': 0,
#  '2004186': 0,
#  '2046505': 1,
#  '2071723': 0,
#  '2130187': 0,
#  '2186129': 0,
#  '2304004': 0,
#  '2304005': 0,
#  '2324839': 0,
#  '2325143': 0,
#  '2382766': 0,
#  '2394677': 0,
#  '256744': 0,
#  '256746': 0,
#  '256750': 0,
#  '2594897': 0,
#  '2604487': 0,
#  '2725017': 0,
#  '2874503': 0,
#  '2943092': 0,
#  '2978577': 0,
# ...

# %%
for qid, text in trec_dl_19.queries_iter():
    print(qid, text)
# Out:
# 156493 do goldfish grow
# 1110199 what is wifi vs bluetooth
# 1063750 why did the us volunterilay enter ww1
# 130510 definition declaratory judgment
# 489204 right pelvic pain causes
# 573724 what are the social determinants of health
# 168216 does legionella pneumophila cause pneumonia
# 1133167 how is the weather in jamaica
# 527433 types of dysarthria from cerebral palsy
# 1037798 who is robert gray
# 915593 what types of food can you cook sous vide
# 264014 how long is life cycle of flea
# 1121402 what can contour plowing reduce
# 962179 when was the salvation army founded
# 1117099 what is a active margin
# 148538 difference between rn and bsn
# 451602 medicare's definition of mechanical ventilation
# 359349 how to find the midsegment of a trapezoid
# 1115776 what is an aml surveillance analyst
# 1112341 what is the daily life of thai people
# 131843 definition of a sigmet
# 104861 cost of interior concrete flooring
# 833860 what is the most popular food in switzerland
# ...
